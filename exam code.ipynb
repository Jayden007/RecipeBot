# %%
from __future__ import unicode_literals
import os
import konlpy
import pickle
import codecs

# %%
from konlpy.utils import pprint

# %%
import tensorflow as tf
import numpy as np

# %%
import re

# %% [markdown]
# # 전처리

# %%
def read_data(filename):
    with codecs.open(filename,'r',encoding='utf8') as f:
        data = [line for line in f.read().splitlines() if line != '']
      #  data = data[1:]   # header 제외
    return data

# %%
temp = read_data('data/[Leopard-Raws] Shokugeki no Souma - 03 RAW (TBS 1280x720 x264 AAC).KRCC.txt')

# %%
pprint(temp)
# Out:
# [﻿전차가 왔당께,
#  그럼 이만 간데이,
#  메구미,
#  정말 가는 거구나,
#  이제 막 13살밖에 안 됐는데,
#  할아버지,
#  걱정 말랑께,
#  그라게,
#  메구미의 요리는,
#  이 지역 최고니께,
#  도쿄에서도 통할 기다,
#  침착하게 공부할 수 있도록,
#  자,
#  학업성취 부적이란다,
#  응,
#  메구미는 소심한 구석이 있으니까,
#  모두 고마워,
#  내가 꼭,
#  훌륭한 요리사가 되어 돌아올 테니!,
#  최후 통보,
#  중등부 3학년<b>　　　　　　　</b>,
#  타도코로 메구미<b>　　　 　　</b>,
#  상기인은 수업 평가가<b>　　　</b>,
#  '불가' 또는 E가 될 경우<b>　　</b>,
#  학칙에 의거 퇴학,
#  학칙에 의거 퇴학,
#  타도코로 메구미,
#  고등학교 1학년 봄,
#  벼랑 끝입니다…,
#  <font color=1E90FF>生まれ変わる</font>,
#  다시 태어나,
#  <font color=1E90FF>今ここで</font>,
#  현재 여기서,
#  <font color=1E90FF>仰いでいた空越えて行く</font>,
#  우러러보던 하늘을 넘어가네,
#  <font color=1E90FF>握り締めた手の平の</font>,
#  꼭 움켜쥔 손바닥에,
#  <font color=1E90FF>その中に希望があったんだ</font>,
#  희망이 있었어,
#  <font Color="FF8200">식극의</font> <font Color="13C7A3">소마</font>,
#  <font color=#FF32B1>http://mglna.tistory.com/,
#  </font>,
#  by 천상(schein),
#  <font color=1E90FF>目の前に広がる景色全部が</font>,
#  눈앞에 펼쳐진 광경 전부가,
#  <font color=1E90FF>実はちっぽけだったと気づいた</font>,
#  실은 조그마한 것이란 걸 깨달았어,
#  <font color=1E90FF>例えば君と出会えば簡単に</font>,
#  예컨대, 너와 만나면 간단히,
#  <font color=1E90FF>世界はひっくり返る</font>,
#  세계는 뒤집히겠지,
#  <font color=1E90FF>知らない事だらけで</font>,
#  모르는 것투성이라,
#  <font color=1E90FF>笑えてくるな</font>,
#  웃음이 나오네,
#  <font color=1E90FF>まだまだ先に行ける証だ</font>,
#  아직 나아갈 수 있는 증거야,
#  <font color=1E90FF>追いかけてた</font>,
#  좇고 있었던,
#  <font color=1E90FF>遥か遠く</font>,
#  아득히 멀리,
#  <font color=1E90FF>譲れない</font>,
#  양보할 수 없는,
#  <font color=1E90FF>思いも連れて</font>,
#  마음을 데리고서,
#  <font color=1E90FF>誰も知らない頂を</font>,
#  아무도 모르는 정상을,
#  <font color=1E90FF>目指していく</font>,
#  향해가네,
#  <font color=1E90FF>全て賭けて</font>,
#  모든 걸 걸고서,
#  그 요리사는 웃지 않는다,
#  이어서 학년장,
#  수여로 넘어가겠습니다,
#  신입생 1학년 총대표,
#  나키리 에리나,
#  네,
#  나키리 에리나,
#  고등부 1학년,
#  에리나 님…,
#  오늘도 아름다우셔,
#  저 미모에 게다가 수석…,
#  그야말로 완전 초인,
#  하루만이라도 데이트,
#  할 수 있다면 난,
#  죽어도 좋아,
#  바보야,
#  허튼소리 하다가,
#  학교에서 말소당한다고,
#  그래,
#  상대는 요리계의 마피아를 이끄는,
#  두목의 손녀라고,
#  그렇지만…,
#  계속해서 식사(式辞)가 있겠습니다,
#  토오츠키 학원 총수,
#  나키리 센자에몬 님,
#  나키리 센자에몬,
#  토오츠키 학원 총수,
#  무, 무서워!,
#  토오츠키 학원을,
#  아니, 일본의 요리,
#  업계를 좌지우지하는,
#  미식의 화신,
#  마피아의 두목의,
#  레벨이 아니라고!,
#  마왕, 요리의 마왕이야!,
#  제군들,
#  고등부 진학,
#  축하한다,
#  제군들은,
#  중등부에서 3년간,
#  조리의 기초 기술을 배우고,
#  식재료에 대한 이해를 더했다,
#  실제로 요리를 하는,
#  조리 교련은 물론이고,
#  각종 좌학, 조리이론,
#  영양학,
#  공중위생학,
#  재배개론,
#  경영학,
#  그리고 지금,
#  고등부 입구에 선 것이지만,
#  앞으로 시험당하는 건,
#  기교나 지식이 아니다,
#  요리사로서 살아갈 기개 그 자체,
#  제군들 중 99%는,
#  1%의 옥을 연마하기 위한,
#  버림돌이다!,
#  버림돌이래,
#  엄청난 말씀이네, 형,
#  응,
#  그러네,
#  작년 1학년 신입생,
#  812명 중,
#  2학년에 진급한 건,
#  76명,
#  무능과 범부는 가차 없이 쳐낸다,
#  천 명의 1학년이,
#  진급할 무렵에는 백 명으로 줄고,
#  졸업까지 도달한 자는,
#  한 손에 꼽을 수 있겠지,
#  그 한 줌의 요리사는,
#  바로 네가!,
#  네가 되는 것이다,
#  연마하라,
#  이상이다,
#  토오츠키 브랜드 파워의 근원은,
#  이 철저한 경쟁에 의한,
#  소수 정예 교육이지,
#  졸업까지 도달하면,
#  평생 요리계의 스타덤을 걷게 된다,
#  하지만,
#  나와 같은 세대인 너희가,
#  가엾게 느껴지네,
#  태어난 순간부터 2위 다툼의,
#  숙명을 타고 났으니까,
#  토오츠키의 정점,
#  그리고 일본 요리계에,
#  군림하는 건 바로 나,
#  나키리 에리나거든,
#  마지막으로 금일부로,
#  편입할 학생을,
#  한 명 소개하겠습니다,
#  나와는 다른 심사로 합격자가 나왔구나,
#  유키히라 소마,
#  저리 가~!,
#  오지 말라고~!,
#  떠올리기만 해도 화가 치미네,
#  뭐, 상관없지,
#  이제 다시 만날 일은 없겠지,
#  됐으니까 빨리 해주세요,
#  그럼 짤막하게,
#  두세 마디만,
#  뭐어어어어엇?!!,
#  저기,
#  유키히라 소마라고 합니다,
#  이 학교에 대해선 솔직히,
#  발판으로만 생각하고 있습니다,
#  뜻하지 않게 편입하게 됐지만,
#  손님 앞에 서본 적도 없는,
#  녀석들에게 질 생각은 없습니다,
#  무슨 말을 하고 싶으냐면,
#  즉, 들어온 이상,
#  정상을 차지할 거거든요,
#  3년간 잘 부탁합니다,
#  이 자식!,
#  더듬지 않고 말했네,
#  시험 때 그…,
#  그게…,
#  나키리였지?,
#  이야, 긴장했네,
#  어릴 때부터 표창장 같은 것과,
#  연이 없었으니까,
#  나 어땠어?,
#  이상하지 않았어?,
#  그런 건 아무래도 상관없어!,
#  유키히라 군,
#  왜 네가 여기에?!,
#  아니,
#  왜냐니,
#  합격 통지가 왔으니 왔지,
#  어째서,
#  그때는 겁먹었다고,
#  맛없다니까,
#  맛있으면 맛있다고,
#  솔직하게 말해,
#  아니…,
#  아닌데,
#  아닌데!,
#  난 이 녀석을 거부했는데,
#  말해보라고,
#  맛있는지,
#  맛없는지,
#  맛없다고!,
#  어라?!,
#  말해두겠는데,
#  난 인정할 수 없어,
#  너도,
#  네 요리도 말이지,
#  착오야, 착오,
#  넌 착오로 토오츠키에 온 거라고,
#  정상을 차지하겠다고?!,
#  웃기지 마,
#  중등부부터 내부 진학자는 모두,
#  최첨단의 가스트로노미를 배워왔다고,
#  위를 올려볼 필요도 없어,
#  바깥 출신 편입생 따윈,
#  그들도 이기지 못할걸?,
#  중등부 3년간이라,
#  뭐?,
#  처음 칼을 잡았던 건 3살 때였지,
#  그 뒤로 12년간,
#  난 조리장에서 살아왔다고,
#  맛없다는 말을 들은 채,
#  가게 이름에 먹칠할 수도 없지,
#  기대하라고,
#  네 입으로 분명히,
#  맛있다고 말하게 해주겠어,
#  내 요리 전부를 다해!,
#  이야~,
#  굉장한 편입생이네,
#  그래도 이 학교에서,
#  살아남기 위해서는,
#  그 정도로 건방진 게 좋을지도?,
#  그럴듯하네~,
#  우리도 힘내자!,
#  그렇지, 메구미?,
#  어라?,
#  메구미는?,
#  어라?,
#  이제 싫어…,
#  분명 내가 버림돌 1등상이야…,
#  고등부 내부 진학,
#  시험은 최하위였고,
#  최종 통보까지…,
#  아니,
#  포기하면 안 돼,
#  도쿄로 보내준,
#  모두의 기대에 부응해야지!,
#  좌우지간,
#  안 그래도 낙제 직전이니까,
#  저 편입해온 사람처럼,
#  나쁘게 튀지 않도록,
#  평온하게 가야 해!,
#  좋아,
#  그 편입생에게는 절대,
#  다가가지 않도록 하자!,
#  그럼 바로,
#  오늘부터 각 교실로,
#  나뉘어 수업을 진행한다,
#  오늘은 이 페어로 조리한다,
#  알겠지?,
#  잘 부탁해,
#  어째서어어어어어?!,
#  <font Color="FF8200">식극의</font> <font Color="13C7A3">소마</font>,
#  <font color=#FF32B1>http://mglna.tistory.com/,
#  </font>,
#  by 천상(schein),
#  하~알~짝,
#  제3조리 실습실,
#  이야~,
#  수업에서 요리하는 건,
#  가정과 조리실습 이후 처음이네,
#  봐라, 저 녀석,
#  그래,
#  시업식 때 건방진 소릴,
#  지껄이던 편입생이다,
#  어차피 입만 산 거겠지,
#  저기,
#  타도코로 양이었던가?,
#  왜 부모님 원수처럼,
#  사람 인(人)자를 써서 삼키고 있어?,
#  이, 이건,
#  긴장하지 않으려고요,
#  긴장?,
#  왜?,
#  전 앞으로 한 번이라도,
#  E평가를 받는다면,
#  퇴학이라서…,
#  엘리트 고등학교란 건 들었지만,
#  너 같은 녀석도 있구나,
#  무사평온하게 살아남자고,
#  생각하자마자…,
#  하필이면 이 사람과,
#  한 조가 되다니…,
#  아, 난 유키히라 소마,
#  소마라고 불러도 돼,
#  잘 부탁해,
#  아, 잘, 부탁…,
#  주, 주위 시선이 따가워…,
#  이 사람은 깨닫지 못한 걸까?,
#  주목,
#  좋은 아침,
#  젊은 견습생(Apprenti)들,
#  안녕하십니까,
#  아, 아아, 아프라노티?,
#  롤랑 샤페르 선생님…,
#  롤랑 샤페르,
#  토오츠키 학원 강사,
#  프랑스 요리 부문 주임,
#  주방에 선 순간부터,
#  롤랑 샤페르,
#  토오츠키 학원 강사,
#  프랑스 요리 부문 주임,
#  맛있는 걸 만들 책임이 생긴다,
#  그것에는,
#  경험이나 입장도 상관없지,
#  내 수업에서는,
#  A를 받지 못한 요리는,
#  모조리 E로 간주한다,
#  기억해둬라,
#  운이 너무 없잖아!,
#  그 샤페르 선생님과,
#  첫 수업부터 마주하다니!,
#  어째 무서워 보이는 선생님이구나,
#  토오츠키에서도 특히,
#  평가가 엄하기로 유명해,
#  작년에도 한 반 50명,
#  전원에게 E를 줘서,
#  그중 18명은 그 수업에서,
#  퇴학이 결정됐대,
#  붙은 별명이,
#  웃지 않는 요리사,
#  헤에~,
#  오늘의 메뉴는,
#  뵈프 부르기뇽,
#  프렌치의 대표 메뉴지만,
#  일단 레시피를 칠판에 적어두마,
#  제한 시간은 2시간,
#  완성한 조부터 내놓아라,
#  그럼 시작하지,
#  조리 개시!,
#  잘게 썬 오이 넣기?,
#  좌우지간 할 수밖에 없어,
#  침착하고,
#  착실하게!,
#  그리고 소마 군도,
#  자신이 있어 보였으니까,
#  요리 솜씨도…,
#  뵈프…,
#  부르, 뭐?,
#  소마 군, 저 요리 만들어본 적…,
#  아니, 없는데?,
#  대충 쇠심줄 조림 같은 거잖아?,
#  뭐, 어떻게든 되겠지,
#  레시피 보고 올게,
#  역시 글렀을 지도…,
#  양송이는 버터로 볶은 뒤,
#  나중에 냄비에…,
#  남은 건 약한 불로,
#  충분히 끓이기만 하면 끝,
#  앞으로 40분 뒤 쇠고기를 꺼낸다,
#  앞으로 39분 뒤 쇠고기를 꺼낸다,
#  앞으로 38분 뒤 쇠고기를 꺼낸다!,
#  타도코로,
#  여기 봐,
#  조미료 종류가 엄청 많네,
#  왠지 나만 긴장한 게 바보 같다,
#  맞다,
#  이틈에 담을 접시 가져와야지,
#  어라?,
#  타도코로,
#  뚜껑 열었어?,
#  응?,
#  안 열었는데,
#  그야 아직 20분은 더 끓여야 하니까,
#  이 하얀 건 뭐야!,
#  소금이야,
#  어째서?!,
#  어, 어쩌지?,
#  어떡해!,
#  이 고기는 이제 못 써,
#  다시 만들어야…,
#  하지만 고기를 부드럽게 만들어서,
#  맛이 밸 때까지,
#  1시간 이상이 걸려…,
#  그 뒤, 소스를 배어드는데,
#  30분은 끓여야 하는데!,
#  남은 시간은 앞으로 30분…,
#  그렇다고 이런 소금 범벅인,
#  요리를 제출했다간,
#  평가 E를 받는 건 확실하고!,
#  엄마…,
#  미안해, 모두들…,
#  이제 글렀당께…,
#  예비 식재료 받아왔어,
#  자, 해볼까,
#  어?,
#  소마 군,
#  하지만 이미 시간 내에 불가능하당께,
#  저 선생님은 제법 괜찮은 소릴 하네,
#  우린 학생이기 전에 요리사지,
#  요리는 무슨 일이 있어도 내놓는다,
#  도와줘,
#  아, 네!,
#  여기,
#  소금이랑 후추랑 부케가르니,
#  좋아,
#  그 큰소리 치던 편입생,
#  뭔가 필사적이네,
#  뭐, 무슨 짓을 해봤자,
#  E가 확정이겠지,
#  그렇겠지,
#  평가 A,
#  좋았어!,
#  다음 조,
#  슬슬 어느 조든 완성될 때인가,
#  우리도 남은 건 소스뿐이야,
#  얼른…,
#  다음 심사 부탁드립니다,
#  완성이다,
#  설마,
#  완성이다!,
#  부드럽군,
#  포크가 튕겨나는 듯해,
#  뭐?!,
#  거짓말,
#  삶는 시간이 충분했을 리…,
#  너희 조는 문제가 있었을 텐데,
#  어떻게 완성했지?,
#  사용한 건 벌꿀,
#  삶기 전 고기에 주물러두고,
#  밑간을 할 때도 넣어봤습니다,
#  벌꿀에는 단백질 분해 효소인,
#  프로테아제가 함유돼 있지,
#  그것이 단단한 쇠 갈빗살에 작용해서,
#  단시간에 부드럽게,
#  완성할 수 있었나,
#  하, 하지만 어떻게 이렇게,
#  벌꿀을 쓸 수 있는 걸 알았어?,
#  옛날에,
#  요리책을 볼 때,
#  파인애플 과즙이 고기를,
#  부드럽게 만든다고 적혀있었는데,
#  파인애플 같은 건,
#  통째로 살 기회가 별로 없으니까,
#  마찬가지로,
#  고기를 부드럽게 만들 게 없을지,
#  이것저것 시험해봤어,
#  벌꿀은 보존도 쉽고,
#  제일 쓰기 편하거든,
#  뭐, 먹어보면 알 거야,
#  타도코로도 말이지,
#  자,
#  황홀해~,
#  끈적끈적~,
#  훌륭해!,
#  샤페르 선생님이,
#  웃었어?!,
#  유키히라 타도코로 페어,
#  평가 A를 주마,
#  다만,
#  내가 A보다 위를,
#  줄 권한이 없는 것이,
#  유감이지만 말이야,
#  변변찮았습니다!,
#  저런 편입생의 요리가,
#  우리보다 위?!,
#  야!,
#  소스가 탔잖아!,
#  큰일이다!,
#  평가 E!,
#  제2조리 실습실,
#  간단했네, 형,
#  그래,
#  평소와 다름없었네,
#  그 편입생과 같은 수업이었다면,
#  박살 내줬을 텐데,
#  소마 군,
#  아, 수고했어,
#  저기…,
#  오늘은 고마워,
#  소마 군 덕분에 나…,
#  됐어,
#  앞으로 잘 부탁해,
#  타도코로,
#  응!,
#  나, 어쩌면 굉장한 사람과,
#  페어가 된 걸지도 몰라,
#  아, 그런데 친해진 기념으로,
#  내 신작 요리 맛보지 않을래?,
#  어?,
#  괜찮아?,
#  먹어보고 싶어,
#  자,
#  어?,
#  저기,
#  오징어 벌꿀 절임이야,
#  오징어의 풍미가,
#  잘못된 방향으로 변모해서,
#  온몸을 더듬는 듯한,
#  맛없음이었습니다,
#  싫어어어어어어어어!,
#  <font color=#FF5675>諦めちゃって良いのに</font>,
#  포기하면 좋을 텐데,
#  <font color=#FF5675>やめちゃえって思うのに</font>,
#  그만두자고 생각하면서도,
#  <font color=#FF5675>逃げ出す事さえ出来なくて</font>,
#  도망칠 수 없어서,
#  <font color=#FF5675>ふらふら　ふらふら</font>,
#  흔들흔들 흔들흔들,
#  <font color=#FF5675>自身がなくてそのせいで</font>,
#  자신이 없는 탓에,
#  <font color=#FF5675>自分自身も出せなくて</font>,
#  자기 자신도 나타내지 못해서,
#  <font color=#FF5675>自身なくしてスパイラル</font>,
#  자신 잃기를 반복,
#  <font color=#FF5675>ぐるぐる　ぐるぐる</font>,
#  뱅글뱅글 뱅글뱅글,
#  <font color=#FF5675>でも出会えたから</font>,
#  하지만 만날 수 있었으니까,
#  <font color=#FF5675>もう見失わないよ</font>,
#  더는 잃어버리지 않겠어,
#  <font color=#FF5675>笑顔があれば要らない何も</font>,
#  미소가 있으면 아무것도 필요 없어,
#  <font color=#FF5675>豪華な品も</font>,
#  호화로운 것도,
#  <font color=#FF5675>派手な飾りも</font>,
#  요란한 장식도,
#  <font color=#FF5675>要らないから</font>,
#  필요 없으니까,
#  <font color=#FF5675>食卓囲もう</font>,
#  식탁에 둘러앉자,
#  <font color=#FF5675>昨日のミスも</font>,
#  전날의 실수도,
#  <font color=#FF5675>不安な明日も</font>,
#  불안한 미래도,
#  <font color=#FF5675>添えて</font>,
#  더해서,
#  <font color=#FF5675>ねえ、要らない何も</font>,
#  저기, 아무것도 필요 없어,
#  <font color=#FF5675>豪華味付けも</font>,
#  호화로운 맛 내기도,
#  <font color=#FF5675>洒落た盛り付けも要らないから</font>,
#  세련된 세팅도 필요 없으니까,
#  <font color=#FF5675>涙の味はもう</font>,
#  눈물의 맛은 이제,
#  <font color=#FF5675>塩っぱいと知っても</font>,
#  짜다는 걸 알았어도,
#  <font color=#FF5675>最後にいつも</font>,
#  마지막엔 항상,
#  <font color=#FF5675>笑うから</font>,
#  웃을 테니까,
#  <font color=#FF5675>それがスパイス</font>,
#  그것이 스파이스,
#  에리나 님이다,
#  또 신작 요리를 시험하시는 걸까,
#  한 번 시식해보고 싶어,
#  에리나 님!,
#  에리나 님, 큰일입니다,
#  무슨 일인가요, 소란스럽게,
#  샤페르 선생님의 수업을,
#  최고 평가로 통과한 모양이에요,
#  그 남자,
#  유키히라 소마가!,
#  내 앞에서,
#  그 이름 입에 담지 말아줄래?,
#  죄, 죄송합니다!,
#  내 성역에 침입한 유일한 오점!,
#  놔둘 수 없어,
#  곧 배제해주겠어,
#  반드시!,
#  오징어 땅콩 버터도 있는데 어때?,
#  그 밖에도 이것저것…,
#  역시 이 사람 싫어어어어어!,
#  다음 화,
#  식극의 소마,
#  네, 네, 네 번째 요리예요,
#  극성의 마리아,
#  드셔보세요,
#  자자자, 다음은 이걸 잡숴봐]

# %%
name_dict = ['소마', '유키히라','나키리', '에리나', '타도코로', '메구미',
            '타쿠미', '알디니', '나키리', '에리스', '토오츠키']

# %%
filter1 = re.compile(r'<font.')
filter2 = re.compile(r'by 천상.')

# %%
pre_chat = []
for sen in temp:
    if ('<' not in sen) & (filter2.match(sen) == None):
        pre_chat.append(sen)

# %%
for sen2 in pre_chat:
    if sen2 == '다시 태어나':
        songIndex = pre_chat.index(sen2)
        
for x in range(songIndex,songIndex+17):
    pre_chat[x] = ''

# %%
pre_chat = [xx for xx in pre_chat if xx != '']

# %%
pprint(pre_chat)
# Out:
# [﻿전차가 왔당께,
#  그럼 이만 간데이,
#  메구미,
#  정말 가는 거구나,
#  이제 막 13살밖에 안 됐는데,
#  할아버지,
#  걱정 말랑께,
#  그라게,
#  메구미의 요리는,
#  이 지역 최고니께,
#  도쿄에서도 통할 기다,
#  침착하게 공부할 수 있도록,
#  자,
#  학업성취 부적이란다,
#  응,
#  메구미는 소심한 구석이 있으니까,
#  모두 고마워,
#  내가 꼭,
#  훌륭한 요리사가 되어 돌아올 테니!,
#  최후 통보,
#  학칙에 의거 퇴학,
#  학칙에 의거 퇴학,
#  타도코로 메구미,
#  고등학교 1학년 봄,
#  벼랑 끝입니다…,
#  향해가네,
#  모든 걸 걸고서,
#  그 요리사는 웃지 않는다,
#  이어서 학년장,
#  수여로 넘어가겠습니다,
#  신입생 1학년 총대표,
#  나키리 에리나,
#  네,
#  나키리 에리나,
#  고등부 1학년,
#  에리나 님…,
#  오늘도 아름다우셔,
#  저 미모에 게다가 수석…,
#  그야말로 완전 초인,
#  하루만이라도 데이트,
#  할 수 있다면 난,
#  죽어도 좋아,
#  바보야,
#  허튼소리 하다가,
#  학교에서 말소당한다고,
#  그래,
#  상대는 요리계의 마피아를 이끄는,
#  두목의 손녀라고,
#  그렇지만…,
#  계속해서 식사(式辞)가 있겠습니다,
#  토오츠키 학원 총수,
#  나키리 센자에몬 님,
#  나키리 센자에몬,
#  토오츠키 학원 총수,
#  무, 무서워!,
#  토오츠키 학원을,
#  아니, 일본의 요리,
#  업계를 좌지우지하는,
#  미식의 화신,
#  마피아의 두목의,
#  레벨이 아니라고!,
#  마왕, 요리의 마왕이야!,
#  제군들,
#  고등부 진학,
#  축하한다,
#  제군들은,
#  중등부에서 3년간,
#  조리의 기초 기술을 배우고,
#  식재료에 대한 이해를 더했다,
#  실제로 요리를 하는,
#  조리 교련은 물론이고,
#  각종 좌학, 조리이론,
#  영양학,
#  공중위생학,
#  재배개론,
#  경영학,
#  그리고 지금,
#  고등부 입구에 선 것이지만,
#  앞으로 시험당하는 건,
#  기교나 지식이 아니다,
#  요리사로서 살아갈 기개 그 자체,
#  제군들 중 99%는,
#  1%의 옥을 연마하기 위한,
#  버림돌이다!,
#  버림돌이래,
#  엄청난 말씀이네, 형,
#  응,
#  그러네,
#  작년 1학년 신입생,
#  812명 중,
#  2학년에 진급한 건,
#  76명,
#  무능과 범부는 가차 없이 쳐낸다,
#  천 명의 1학년이,
#  진급할 무렵에는 백 명으로 줄고,
#  졸업까지 도달한 자는,
#  한 손에 꼽을 수 있겠지,
#  그 한 줌의 요리사는,
#  바로 네가!,
#  네가 되는 것이다,
#  연마하라,
#  이상이다,
#  토오츠키 브랜드 파워의 근원은,
#  이 철저한 경쟁에 의한,
#  소수 정예 교육이지,
#  졸업까지 도달하면,
#  평생 요리계의 스타덤을 걷게 된다,
#  하지만,
#  나와 같은 세대인 너희가,
#  가엾게 느껴지네,
#  태어난 순간부터 2위 다툼의,
#  숙명을 타고 났으니까,
#  토오츠키의 정점,
#  그리고 일본 요리계에,
#  군림하는 건 바로 나,
#  나키리 에리나거든,
#  마지막으로 금일부로,
#  편입할 학생을,
#  한 명 소개하겠습니다,
#  나와는 다른 심사로 합격자가 나왔구나,
#  유키히라 소마,
#  저리 가~!,
#  오지 말라고~!,
#  떠올리기만 해도 화가 치미네,
#  뭐, 상관없지,
#  이제 다시 만날 일은 없겠지,
#  됐으니까 빨리 해주세요,
#  그럼 짤막하게,
#  두세 마디만,
#  뭐어어어어엇?!!,
#  저기,
#  유키히라 소마라고 합니다,
#  이 학교에 대해선 솔직히,
#  발판으로만 생각하고 있습니다,
#  뜻하지 않게 편입하게 됐지만,
#  손님 앞에 서본 적도 없는,
#  녀석들에게 질 생각은 없습니다,
#  무슨 말을 하고 싶으냐면,
#  즉, 들어온 이상,
#  정상을 차지할 거거든요,
#  3년간 잘 부탁합니다,
#  이 자식!,
#  더듬지 않고 말했네,
#  시험 때 그…,
#  그게…,
#  나키리였지?,
#  이야, 긴장했네,
#  어릴 때부터 표창장 같은 것과,
#  연이 없었으니까,
#  나 어땠어?,
#  이상하지 않았어?,
#  그런 건 아무래도 상관없어!,
#  유키히라 군,
#  왜 네가 여기에?!,
#  아니,
#  왜냐니,
#  합격 통지가 왔으니 왔지,
#  어째서,
#  그때는 겁먹었다고,
#  맛없다니까,
#  맛있으면 맛있다고,
#  솔직하게 말해,
#  아니…,
#  아닌데,
#  아닌데!,
#  난 이 녀석을 거부했는데,
#  말해보라고,
#  맛있는지,
#  맛없는지,
#  맛없다고!,
#  어라?!,
#  말해두겠는데,
#  난 인정할 수 없어,
#  너도,
#  네 요리도 말이지,
#  착오야, 착오,
#  넌 착오로 토오츠키에 온 거라고,
#  정상을 차지하겠다고?!,
#  웃기지 마,
#  중등부부터 내부 진학자는 모두,
#  최첨단의 가스트로노미를 배워왔다고,
#  위를 올려볼 필요도 없어,
#  바깥 출신 편입생 따윈,
#  그들도 이기지 못할걸?,
#  중등부 3년간이라,
#  뭐?,
#  처음 칼을 잡았던 건 3살 때였지,
#  그 뒤로 12년간,
#  난 조리장에서 살아왔다고,
#  맛없다는 말을 들은 채,
#  가게 이름에 먹칠할 수도 없지,
#  기대하라고,
#  네 입으로 분명히,
#  맛있다고 말하게 해주겠어,
#  내 요리 전부를 다해!,
#  이야~,
#  굉장한 편입생이네,
#  그래도 이 학교에서,
#  살아남기 위해서는,
#  그 정도로 건방진 게 좋을지도?,
#  그럴듯하네~,
#  우리도 힘내자!,
#  그렇지, 메구미?,
#  어라?,
#  메구미는?,
#  어라?,
#  이제 싫어…,
#  분명 내가 버림돌 1등상이야…,
#  고등부 내부 진학,
#  시험은 최하위였고,
#  최종 통보까지…,
#  아니,
#  포기하면 안 돼,
#  도쿄로 보내준,
#  모두의 기대에 부응해야지!,
#  좌우지간,
#  안 그래도 낙제 직전이니까,
#  저 편입해온 사람처럼,
#  나쁘게 튀지 않도록,
#  평온하게 가야 해!,
#  좋아,
#  그 편입생에게는 절대,
#  다가가지 않도록 하자!,
#  그럼 바로,
#  오늘부터 각 교실로,
#  나뉘어 수업을 진행한다,
#  오늘은 이 페어로 조리한다,
#  알겠지?,
#  잘 부탁해,
#  어째서어어어어어?!,
#  하~알~짝,
#  제3조리 실습실,
#  이야~,
#  수업에서 요리하는 건,
#  가정과 조리실습 이후 처음이네,
#  봐라, 저 녀석,
#  그래,
#  시업식 때 건방진 소릴,
#  지껄이던 편입생이다,
#  어차피 입만 산 거겠지,
#  저기,
#  타도코로 양이었던가?,
#  왜 부모님 원수처럼,
#  사람 인(人)자를 써서 삼키고 있어?,
#  이, 이건,
#  긴장하지 않으려고요,
#  긴장?,
#  왜?,
#  전 앞으로 한 번이라도,
#  E평가를 받는다면,
#  퇴학이라서…,
#  엘리트 고등학교란 건 들었지만,
#  너 같은 녀석도 있구나,
#  무사평온하게 살아남자고,
#  생각하자마자…,
#  하필이면 이 사람과,
#  한 조가 되다니…,
#  아, 난 유키히라 소마,
#  소마라고 불러도 돼,
#  잘 부탁해,
#  아, 잘, 부탁…,
#  주, 주위 시선이 따가워…,
#  이 사람은 깨닫지 못한 걸까?,
#  주목,
#  좋은 아침,
#  젊은 견습생(Apprenti)들,
#  안녕하십니까,
#  아, 아아, 아프라노티?,
#  롤랑 샤페르 선생님…,
#  롤랑 샤페르,
#  토오츠키 학원 강사,
#  프랑스 요리 부문 주임,
#  주방에 선 순간부터,
#  롤랑 샤페르,
#  토오츠키 학원 강사,
#  프랑스 요리 부문 주임,
#  맛있는 걸 만들 책임이 생긴다,
#  그것에는,
#  경험이나 입장도 상관없지,
#  내 수업에서는,
#  A를 받지 못한 요리는,
#  모조리 E로 간주한다,
#  기억해둬라,
#  운이 너무 없잖아!,
#  그 샤페르 선생님과,
#  첫 수업부터 마주하다니!,
#  어째 무서워 보이는 선생님이구나,
#  토오츠키에서도 특히,
#  평가가 엄하기로 유명해,
#  작년에도 한 반 50명,
#  전원에게 E를 줘서,
#  그중 18명은 그 수업에서,
#  퇴학이 결정됐대,
#  붙은 별명이,
#  웃지 않는 요리사,
#  헤에~,
#  오늘의 메뉴는,
#  뵈프 부르기뇽,
#  프렌치의 대표 메뉴지만,
#  일단 레시피를 칠판에 적어두마,
#  제한 시간은 2시간,
#  완성한 조부터 내놓아라,
#  그럼 시작하지,
#  조리 개시!,
#  잘게 썬 오이 넣기?,
#  좌우지간 할 수밖에 없어,
#  침착하고,
#  착실하게!,
#  그리고 소마 군도,
#  자신이 있어 보였으니까,
#  요리 솜씨도…,
#  뵈프…,
#  부르, 뭐?,
#  소마 군, 저 요리 만들어본 적…,
#  아니, 없는데?,
#  대충 쇠심줄 조림 같은 거잖아?,
#  뭐, 어떻게든 되겠지,
#  레시피 보고 올게,
#  역시 글렀을 지도…,
#  양송이는 버터로 볶은 뒤,
#  나중에 냄비에…,
#  남은 건 약한 불로,
#  충분히 끓이기만 하면 끝,
#  앞으로 40분 뒤 쇠고기를 꺼낸다,
#  앞으로 39분 뒤 쇠고기를 꺼낸다,
#  앞으로 38분 뒤 쇠고기를 꺼낸다!,
#  타도코로,
#  여기 봐,
#  조미료 종류가 엄청 많네,
#  왠지 나만 긴장한 게 바보 같다,
#  맞다,
#  이틈에 담을 접시 가져와야지,
#  어라?,
#  타도코로,
#  뚜껑 열었어?,
#  응?,
#  안 열었는데,
#  그야 아직 20분은 더 끓여야 하니까,
#  이 하얀 건 뭐야!,
#  소금이야,
#  어째서?!,
#  어, 어쩌지?,
#  어떡해!,
#  이 고기는 이제 못 써,
#  다시 만들어야…,
#  하지만 고기를 부드럽게 만들어서,
#  맛이 밸 때까지,
#  1시간 이상이 걸려…,
#  그 뒤, 소스를 배어드는데,
#  30분은 끓여야 하는데!,
#  남은 시간은 앞으로 30분…,
#  그렇다고 이런 소금 범벅인,
#  요리를 제출했다간,
#  평가 E를 받는 건 확실하고!,
#  엄마…,
#  미안해, 모두들…,
#  이제 글렀당께…,
#  예비 식재료 받아왔어,
#  자, 해볼까,
#  어?,
#  소마 군,
#  하지만 이미 시간 내에 불가능하당께,
#  저 선생님은 제법 괜찮은 소릴 하네,
#  우린 학생이기 전에 요리사지,
#  요리는 무슨 일이 있어도 내놓는다,
#  도와줘,
#  아, 네!,
#  여기,
#  소금이랑 후추랑 부케가르니,
#  좋아,
#  그 큰소리 치던 편입생,
#  뭔가 필사적이네,
#  뭐, 무슨 짓을 해봤자,
#  E가 확정이겠지,
#  그렇겠지,
#  평가 A,
#  좋았어!,
#  다음 조,
#  슬슬 어느 조든 완성될 때인가,
#  우리도 남은 건 소스뿐이야,
#  얼른…,
#  다음 심사 부탁드립니다,
#  완성이다,
#  설마,
#  완성이다!,
#  부드럽군,
#  포크가 튕겨나는 듯해,
#  뭐?!,
#  거짓말,
#  삶는 시간이 충분했을 리…,
#  너희 조는 문제가 있었을 텐데,
#  어떻게 완성했지?,
#  사용한 건 벌꿀,
#  삶기 전 고기에 주물러두고,
#  밑간을 할 때도 넣어봤습니다,
#  벌꿀에는 단백질 분해 효소인,
#  프로테아제가 함유돼 있지,
#  그것이 단단한 쇠 갈빗살에 작용해서,
#  단시간에 부드럽게,
#  완성할 수 있었나,
#  하, 하지만 어떻게 이렇게,
#  벌꿀을 쓸 수 있는 걸 알았어?,
#  옛날에,
#  요리책을 볼 때,
#  파인애플 과즙이 고기를,
#  부드럽게 만든다고 적혀있었는데,
#  파인애플 같은 건,
#  통째로 살 기회가 별로 없으니까,
#  마찬가지로,
#  고기를 부드럽게 만들 게 없을지,
#  이것저것 시험해봤어,
#  벌꿀은 보존도 쉽고,
#  제일 쓰기 편하거든,
#  뭐, 먹어보면 알 거야,
#  타도코로도 말이지,
#  자,
#  황홀해~,
#  끈적끈적~,
#  훌륭해!,
#  샤페르 선생님이,
#  웃었어?!,
#  유키히라 타도코로 페어,
#  평가 A를 주마,
#  다만,
#  내가 A보다 위를,
#  줄 권한이 없는 것이,
#  유감이지만 말이야,
#  변변찮았습니다!,
#  저런 편입생의 요리가,
#  우리보다 위?!,
#  야!,
#  소스가 탔잖아!,
#  큰일이다!,
#  평가 E!,
#  제2조리 실습실,
#  간단했네, 형,
#  그래,
#  평소와 다름없었네,
#  그 편입생과 같은 수업이었다면,
#  박살 내줬을 텐데,
#  소마 군,
#  아, 수고했어,
#  저기…,
#  오늘은 고마워,
#  소마 군 덕분에 나…,
#  됐어,
#  앞으로 잘 부탁해,
#  타도코로,
#  응!,
#  나, 어쩌면 굉장한 사람과,
#  페어가 된 걸지도 몰라,
#  아, 그런데 친해진 기념으로,
#  내 신작 요리 맛보지 않을래?,
#  어?,
#  괜찮아?,
#  먹어보고 싶어,
#  자,
#  어?,
#  저기,
#  오징어 벌꿀 절임이야,
#  오징어의 풍미가,
#  잘못된 방향으로 변모해서,
#  온몸을 더듬는 듯한,
#  맛없음이었습니다,
#  싫어어어어어어어어!,
#  포기하면 좋을 텐데,
#  그만두자고 생각하면서도,
#  도망칠 수 없어서,
#  흔들흔들 흔들흔들,
#  자신이 없는 탓에,
#  자기 자신도 나타내지 못해서,
#  자신 잃기를 반복,
#  뱅글뱅글 뱅글뱅글,
#  하지만 만날 수 있었으니까,
#  더는 잃어버리지 않겠어,
#  미소가 있으면 아무것도 필요 없어,
#  호화로운 것도,
#  요란한 장식도,
#  필요 없으니까,
#  식탁에 둘러앉자,
#  전날의 실수도,
#  불안한 미래도,
#  더해서,
#  저기, 아무것도 필요 없어,
#  호화로운 맛 내기도,
#  세련된 세팅도 필요 없으니까,
#  눈물의 맛은 이제,
#  짜다는 걸 알았어도,
#  마지막엔 항상,
#  웃을 테니까,
#  그것이 스파이스,
#  에리나 님이다,
#  또 신작 요리를 시험하시는 걸까,
#  한 번 시식해보고 싶어,
#  에리나 님!,
#  에리나 님, 큰일입니다,
#  무슨 일인가요, 소란스럽게,
#  샤페르 선생님의 수업을,
#  최고 평가로 통과한 모양이에요,
#  그 남자,
#  유키히라 소마가!,
#  내 앞에서,
#  그 이름 입에 담지 말아줄래?,
#  죄, 죄송합니다!,
#  내 성역에 침입한 유일한 오점!,
#  놔둘 수 없어,
#  곧 배제해주겠어,
#  반드시!,
#  오징어 땅콩 버터도 있는데 어때?,
#  그 밖에도 이것저것…,
#  역시 이 사람 싫어어어어어!,
#  다음 화,
#  식극의 소마,
#  네, 네, 네 번째 요리예요,
#  극성의 마리아,
#  드셔보세요,
#  자자자, 다음은 이걸 잡숴봐]

# %%
def get_training_data_by_disintegration(sentence):
    disintegrated_sentence = konlpy.tag.Twitter().pos(sentence, norm=True, stem=True) 
    original_sentence = konlpy.tag.Twitter().pos(sentence) 
    inputData = []     
    outputData = [] 
    is_asking = False 
    for w, t in disintegrated_sentence:
        if w in name_dict:
            w = 'NAME'    
        if t not in ['Eomi', 'Josa', 'Number', 'KoreanParticle', 'Punctuation']:            
            inputData.append(w) 
    for w, t in original_sentence: 
        if w in name_dict:
            w = 'NAME'
        if t not in ['Number', 'Punctuation']: 
            outputData.append(w) 
    if original_sentence[-1][1] == 'Punctuation' and original_sentence[-1][0] == "?": 
        if len(inputData) != 0 and len(outputData) != 0:            
            is_asking = True # To extract ask-response raw data  
    
    return ' '.join(inputData), ' '.join(outputData), is_asking

# %%
inputd, outputd, ask = get_training_data_by_disintegration(pre_chat[280])

# %%
pprint(inputd)
# Out:
# A 를 받다 못 요리

# %%
pprint(outputd)
# Out:
# A 를 받지 못 한 요리 는

# %% [markdown]
# # Knowledge Engine

# %% [markdown]
# 일단 스킵

# %% [markdown]
# # Grammar model

# %%
from tensorflow.contrib import learn

# %%
n_disintegrated_words = 1
MAX_DOCUMENT_LENGTH = 20
n_recovered_words = 5
HIDDEN_SIZE = 25 
EMBEDDING_SIZE = 25 

def grammar_model(X, y): 
    word_vectors = learn.ops.categorical_variable(X, 
                                                  n_classes=n_disintegrated_words, 
                                                  embedding_size=EMBEDDING_SIZE, 
                                                  name='words') 
    in_X, in_y, out_y = learn.ops.seq2seq_inputs(word_vectors, y, MAX_DOCUMENT_LENGTH, MAX_DOCUMENT_LENGTH) 
    encoder_cell = tf.nn.rnn_cell.GRUCell(HIDDEN_SIZE) 
    decoder_cell = tf.nn.rnn_cell.OutputProjectionWrapper(tf.nn.rnn_cell.GRUCell(HIDDEN_SIZE), n_recovered_words)
    decoding, _, sampling_decoding, _ = learn.ops.rnn_seq2seq(in_X, in_y, 
                                                              encoder_cell, decoder_cell=decoder_cell) 
    return learn.ops.sequence_classifier(decoding, out_y, sampling_decoding)

# %%
grammar_model(inputd,outputd)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-bbf0826f39ed> in <module>()
# ----> 1 grammar_model(inputd,outputd)
#
# <ipython-input-15-9abad3b6e9ee> in grammar_model(X, y)
#       8     word_vectors = learn.ops.categorical_variable(X,
#       9                                                   n_classes=n_disintegrated_words,
# ---> 10                                                   embedding_size=EMBEDDING_SIZE,
#      11                                                   )
#      12     in_X, in_y, out_y = learn.ops.seq2seq_inputs(word_vectors, y, MAX_DOCUMENT_LENGTH, MAX_DOCUMENT_LENGTH)
#
# TypeError: categorical_variable() takes exactly 4 arguments (3 given)

# %% [markdown]
# # Tone generator

# %% [markdown]
# * 3-layer sequence-to-sequence model
# * Almost same as grammar model(training set is different)
# <hr>
#
# * Input : sentence without tones
# * Output : sentence with tones
# * Data : Normal sentences from various conversation sources
